# %% [markdown]
# <a href="https://colab.research.google.com/github/YaserMarey/my_openai_colab/blob/master/semantically_searchable_video/semantically_searchable_arabic_language_video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Steps:
#  - Download video from YouTube
#  - Transcript video using openai whisper
#  - Combine segments for a more meaningful chunks
#  - Text embed transcript segments
#  - Text embed question
#  - Calculate similarity

# %%
# !pip install openai pytube tiktoken
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.2-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 1.3 MB/s eta 0:00:00
# Collecting pytube
#   Downloading pytube-12.1.2-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 2.8 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/dist-packages (from openai) (2.25.1)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.5 MB/s eta 0:00:00
# Collecting requests>=2.20
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.9/dist-packages (from tiktoken) (2022.6.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (1.26.15)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 10.8 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 1.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (22.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 2.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 9.6 MB/s eta 0:00:00
# Installing collected packages: pytube, multidict, frozenlist, charset-normalizer, async-timeout, yarl, requests, aiosignal, tiktoken, aiohttp, openai
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 charset-normalizer-3.1.0 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.2 pytube-12.1.2 requests-2.28.2 tiktoken-0.3.1 yarl-1.8.2

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-kn1r391x
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-kn1r391x
#   Resolved https://github.com/openai/whisper.git to commit 6dea21fd7f7253bfe450f1e2512a0fe47ee2d258
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tiktoken==0.3.1 in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (0.3.1)
# Collecting triton==2.0.0
#   Downloading triton-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (1.22.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (1.13.1+cu116)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (0.56.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (9.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai-whisper==20230314) (4.65.0)
# Collecting ffmpeg-python==0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from ffmpeg-python==0.2.0->openai-whisper==20230314) (0.16.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.9/dist-packages (from tiktoken==0.3.1->openai-whisper==20230314) (2.28.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.9/dist-packages (from tiktoken==0.3.1->openai-whisper==20230314) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->openai-whisper==20230314) (3.9.0)
# Collecting lit
#   Downloading lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 KB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->openai-whisper==20230314) (3.22.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->openai-whisper==20230314) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba->openai-whisper==20230314) (63.4.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch->openai-whisper==20230314) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230314) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230314) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230314) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.26.0->tiktoken==0.3.1->openai-whisper==20230314) (1.26.15)
# Building wheels for collected packages: openai-whisper, lit
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=796926 sha256=49b3c12a13afc7e0e9d8bf46dbdcfce9a66da670cccec9fd21c1e927079a9b15
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c_nx0bne/wheels/fe/03/29/e7919208d11b4ab32972cb448bb84a9a675d92cd52c9a48341
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=90003 sha256=ac0282a1c509895fb6b32ce06bcd830d4ed5fcf416fca494ea53fd43d4027b8d
#   Stored in directory: /root/.cache/pip/wheels/b7/68/18/2ad49b416abb9139c8217c349fd9df0674da8f0d1952db2ea5
# Successfully built openai-whisper lit
# Installing collected packages: lit, ffmpeg-python, triton, openai-whisper
# Successfully installed ffmpeg-python-0.2.0 lit-15.0.7 openai-whisper-20230314 triton-2.0.0

# %%
from pytube import YouTube
youtube_video_url = "https://www.youtube.com/watch?v=kSu7fNDKqvM"
youtube_video = YouTube(youtube_video_url)
audio = youtube_video.streams.get_audio_only().download()
# Out:
# /usr/local/lib/python3.8/dist-packages/whisper/transcribe.py:113: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
import whisper

# %%
model = whisper.load_model('base')
transcript_output = model.transcribe(audio)
transcript_output

# %%
model = whisper.load_model('small')
transcript_output = model.transcribe(audio)
transcript_output

# %%
model = whisper.load_model('medium')
transcript_output = model.transcribe(audio)
transcript_output

# %%
model = whisper.load_model('large')
transcript_output = model.transcribe(audio)
transcript_output

# %%
transcript_data = []
for segment in transcript_output['segments']:
        transcript_data.append({
                "id": f"{youtube_video_url}&t={segment['start']}s",
                "text": segment["text"].strip(),
                "start": segment['start'],
                "end": segment['end']
        })
# Out:
# [{'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=0.0s',
#   'text': 'So Catholics have the Vatican.',
#   'start': 0.0,
#   'end': 7.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=7.0s',
#   'text': 'Soccer fans, old Trapperton Manchester.',
#   'start': 7.0,
#   'end': 10.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=10.0s',
#   'text': "And for car guys like me, Jay Leno's garage.",
#   'start': 10.0,
#   'end': 13.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=13.0s',
#   'text': 'Jay, thanks again for bringing us here.',
#   'start': 13.0,
#   'end': 15.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=15.0s',
#   'text': "Thank you guys for wondering where they're going.",
#   'start': 15.0,
#   'end': 17.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=17.0s',
#   'text': 'Catholics have the Vatican.',
#   'start': 17.0,
#   'end': 18.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=18.0s',
#   'text': 'I go, oh, what is it?',
#   'start': 18.0,
#   'end': 19.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=19.0s',
#   'text': "It's totally different.",
#   'start': 19.0,
#   'end': 20.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=20.0s',
#   'text': 'I am in the wrong, oh, I see.',
#   'start': 20.0,
#   'end': 21.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=21.0s',
#   'text': 'But you guys see, you make you comprise.',
#   'start': 21.0,
#   'end': 23.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=23.0s',
#   'text': 'Yeah, you know.',
#   'start': 23.0,
#   'end': 24.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=24.0s',
#   'text': "That's why you live in the Vatican.",
#   'start': 24.0,
#   'end': 25.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=25.0s',
#   'text': "You know, you're in the Vatican.",
#   'start': 25.0,
#   'end': 26.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=26.0s',
#   'text': "You know, you're in the Vatican.",
#   'start': 26.0,
#   'end': 27.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=27.0s',
#   'text': "You know, you're in the Vatican.",
#   'start': 27.0,
#   'end': 28.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=28.0s',
#   'text': "You're in the Vatican.",
#   'start': 28.0,
#   'end': 29.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=29.0s',
#   'text': "You know, that's why you live people finish what they're saying.",
#   'start': 29.0,
#   'end': 32.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=32.0s',
#   'text': 'You know, I try, right?',
#   'start': 32.0,
#   'end': 33.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=33.0s',
#   'text': 'I try.',
#   'start': 33.0,
#   'end': 34.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=34.0s',
#   'text': 'So, anyway, thanks again for having us here.',
#   'start': 34.0,
#   'end': 35.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=35.0s',
#   'text': 'Sure.',
#   'start': 35.0,
#   'end': 36.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=36.0s',
#   'text': 'On hallowed ground, if you will.',
#   'start': 36.0,
#   'end': 37.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=37.0s',
#   'text': 'Well, not really.',
#   'start': 37.0,
#   'end': 38.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=38.0s',
#   'text': "I mean, it's a garage and everything here runs.",
#   'start': 38.0,
#   'end': 40.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=40.0s',
#   'text': 'And rolls, explodes, makes noise.',
#   'start': 40.0,
#   'end': 42.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=42.0s',
#   'text': "I mean, that's sort of the fun thing.",
#   'start': 42.0,
#   'end': 44.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=44.0s',
#   'text': "I didn't set out to have a collection.",
#   'start': 44.0,
#   'end': 45.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=45.0s',
#   'text': 'I just never sold anything.',
#   'start': 45.0,
#   'end': 47.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=47.0s',
#   'text': 'And some of the cars are very valuable.',
#   'start': 47.0,
#   'end': 49.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=49.0s',
#   'text': 'But some of just cars I like, Corvayers, Ford Falcons.',
#   'start': 49.0,
#   'end': 52.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=52.0s',
#   'text': 'Cars I go up with, you know, type of thing.',
#   'start': 52.0,
#   'end': 55.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=55.0s',
#   'text': 'And the collection runs the gamut of older classic cars.',
#   'start': 55.0,
#   'end': 58.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=58.0s',
#   'text': 'Newer, Ford Falcons.',
#   'start': 58.0,
#   'end': 59.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=59.0s',
#   'text': "Yeah, there's no theme to this.",
#   'start': 59.0,
#   'end': 61.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=61.0s',
#   'text': 'You know, I hate when people only have red cars, you know,',
#   'start': 61.0,
#   'end': 64.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=64.0s',
#   'text': 'or something like that.',
#   'start': 64.0,
#   'end': 65.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=65.0s',
#   'text': "You know, it's just, I guess the theme would be",
#   'start': 65.0,
#   'end': 68.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=68.0s',
#   'text': 'any kind of historical or technical importance.',
#   'start': 68.0,
#   'end': 71.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=71.0s',
#   'text': 'Anything that was a noble failure, the double steam car.',
#   'start': 71.0,
#   'end': 76.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=76.0s',
#   'text': 'Even the Corvayers was not considered successful.',
#   'start': 76.0,
#   'end': 79.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=79.0s',
#   'text': 'But they sold 1.8 million.',
#   'start': 79.0,
#   'end': 81.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=81.0s',
#   'text': 'Imagine you sell 1.8 million of anything now.',
#   'start': 81.0,
#   'end': 83.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=83.0s',
#   'text': 'They make your president of the company.',
#   'start': 83.0,
#   'end': 85.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=85.0s',
#   'text': 'But in the 60s, the must-hang sold 3 million.',
#   'start': 85.0,
#   'end': 88.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=88.0s',
#   'text': 'Yeah.',
#   'start': 88.0,
#   'end': 89.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=89.0s',
#   'text': '1.8 million.',
#   'start': 89.0,
#   'end': 90.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=90.0s',
#   'text': 'What is that?',
#   'start': 90.0,
#   'end': 91.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=91.0s',
#   'text': "You know, I mean, it's almost funny by comparison.",
#   'start': 91.0,
#   'end': 93.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=93.0s',
#   'text': 'I kind of shocked me because knowing that now the reputation of the Corvayers',
#   'start': 93.0,
#   'end': 95.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=95.0s',
#   'text': 'being a sort of a car that was like a lemon in some sense.',
#   'start': 95.0,
#   'end': 98.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=98.0s',
#   'text': 'But not the Corvayers was a very innovative automobile.',
#   'start': 98.0,
#   'end': 102.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=102.0s',
#   'text': "I think it's one of the greatest American designs of all time.",
#   'start': 102.0,
#   'end': 105.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=105.0s',
#   'text': 'When you look at a 60-TX course and now,',
#   'start': 105.0,
#   'end': 108.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=108.0s',
#   'text': "I'll take it to a show and people go,",
#   'start': 108.0,
#   'end': 110.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=110.0s',
#   'text': 'is this a carmageer?',
#   'start': 110.0,
#   'end': 111.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=111.0s',
#   'text': 'Is this European?',
#   'start': 111.0,
#   'end': 112.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=112.0s',
#   'text': 'Is this some kind of a bar?',
#   'start': 112.0,
#   'end': 114.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=114.0s',
#   'text': "No, it's a boy.",
#   'start': 114.0,
#   'end': 115.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=115.0s',
#   'text': "You know, they've never heard of a car.",
#   'start': 115.0,
#   'end': 117.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=117.0s',
#   'text': "You know, I've only heard of it because of this sort of the big,",
#   'start': 117.0,
#   'end': 120.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=120.0s',
#   'text': 'big fascination in classic cars these days.',
#   'start': 120.0,
#   'end': 122.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=122.0s',
#   'text': 'Right.',
#   'start': 122.0,
#   'end': 123.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=123.0s',
#   'text': 'And market is sort of really kind of exploding.',
#   'start': 123.0,
#   'end': 125.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=125.0s',
#   'text': 'And you know, we just had Monterey car week wrap up.',
#   'start': 125.0,
#   'end': 127.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=127.0s',
#   'text': 'Hmm.',
#   'start': 127.0,
#   'end': 128.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=128.0s',
#   'text': 'Haggerty said there was $470 million in sales at the auctions this year,',
#   'start': 128.0,
#   'end': 132.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=132.0s',
#   'text': "blowing away 2015's record year.",
#   'start': 132.0,
#   'end': 135.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=135.0s',
#   'text': 'Right.',
#   'start': 135.0,
#   'end': 136.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=136.0s',
#   'text': 'What do you think is going on in the classic?',
#   'start': 136.0,
#   'end': 137.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=137.0s',
#   'text': 'Well, when money goes down,',
#   'start': 137.0,
#   'end': 141.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=141.0s',
#   'text': 'that art, automobiles, collectible guns, things go up.',
#   'start': 141.0,
#   'end': 146.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=146.0s',
#   'text': 'People put their money in something more tangible.',
#   'start': 146.0,
#   'end': 148.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=148.0s',
#   'text': "Well, I'm going to lose my shirt.",
#   'start': 148.0,
#   'end': 150.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=150.0s',
#   'text': 'I might as well enjoy doing it.',
#   'start': 150.0,
#   'end': 152.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=152.0s',
#   'text': 'So instead of putting it in a 401k or something,',
#   'start': 152.0,
#   'end': 155.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=155.0s',
#   'text': "I'll buy something I could use and enjoy and hopefully it goes up value.",
#   'start': 155.0,
#   'end': 158.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=158.0s',
#   'text': 'I mean, this is fairly recent in the sense of 25 years or 30.',
#   'start': 158.0,
#   'end': 164.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=164.0s',
#   'text': 'You know, when I was a kid,',
#   'start': 164.0,
#   'end': 166.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=166.0s',
#   'text': 'my dad would always amaze that somebody would pay more for an old car',
#   'start': 166.0,
#   'end': 170.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=170.0s',
#   'text': 'than a new car.',
#   'start': 170.0,
#   'end': 171.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=171.0s',
#   'text': 'My dad would get a new Cadillac.',
#   'start': 171.0,
#   'end': 173.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=173.0s',
#   'text': 'Why would you buy a 30-year old?',
#   'start': 173.0,
#   'end': 175.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=175.0s',
#   'text': 'He got a brand new Cadillac.',
#   'start': 175.0,
#   'end': 176.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=176.0s',
#   'text': 'I mean, it made no sense to him.',
#   'start': 176.0,
#   'end': 179.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=179.0s',
#   'text': "He just didn't get it, you know?",
#   'start': 179.0,
#   'end': 181.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=181.0s',
#   'text': 'And it was just a different time.',
#   'start': 181.0,
#   'end': 183.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=183.0s',
#   'text': "And it's only, I mean, my brother bought a Porsche Speedster,",
#   'start': 183.0,
#   'end': 188.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=188.0s',
#   'text': 'a 58-poor Speedster for $800.',
#   'start': 188.0,
#   'end': 191.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=191.0s',
#   'text': 'I think in 68, fixed it up, sold with a 1200.',
#   'start': 191.0,
#   'end': 197.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=197.0s',
#   'text': 'My father, oh my God, take that.',
#   'start': 197.0,
#   'end': 200.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=200.0s',
#   'text': 'Get it out of here.',
#   'start': 200.0,
#   'end': 203.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=203.0s',
#   'text': 'Get the money.',
#   'start': 203.0,
#   'end': 204.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=204.0s',
#   'text': "My dad couldn't believe he made $400 profit.",
#   'start': 204.0,
#   'end': 206.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=206.0s',
#   'text': 'And more recently, a friend of mine, oh, well,',
#   'start': 206.0,
#   'end': 209.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=209.0s',
#   'text': 'this is a while ago, two, 20 years, almost.',
#   'start': 209.0,
#   'end': 212.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=212.0s',
#   'text': 'He bought an F1 McLaren for $8,900,000.',
#   'start': 212.0,
#   'end': 216.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=216.0s',
#   'text': "That's it?",
#   'start': 216.0,
#   'end': 217.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=217.0s',
#   'text': 'Well, this is one that was new.',
#   'start': 217.0,
#   'end': 219.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=219.0s',
#   'text': "Oh, it's new.",
#   'start': 219.0,
#   'end': 220.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=220.0s',
#   'text': 'And when the infusion has got an offer of $1.3 million.',
#   'start': 220.0,
#   'end': 222.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=222.0s',
#   'text': 'And he loved the car, but he said,',
#   'start': 222.0,
#   'end': 224.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=224.0s',
#   'text': "I'm never going to see that kind of profit again.",
#   'start': 224.0,
#   'end': 226.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=226.0s',
#   'text': "And he sold it, and it'll cause now there worth $20 million.",
#   'start': 226.0,
#   'end': 229.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=229.0s',
#   'text': 'So this idea is cars as investments is fairly new.',
#   'start': 229.0,
#   'end': 234.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=234.0s',
#   'text': "I mean, to me, I don't look at it as investments",
#   'start': 234.0,
#   'end': 236.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=236.0s',
#   'text': 'because I would sell my home first.',
#   'start': 236.0,
#   'end': 238.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=238.0s',
#   'text': 'Everything else would go first.',
#   'start': 238.0,
#   'end': 241.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=241.0s',
#   'text': "So the idea that it's worth a lot, well,",
#   'start': 241.0,
#   'end': 244.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=244.0s',
#   'text': "it's very nice and it makes you look smart.",
#   'start': 244.0,
#   'end': 246.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=246.0s',
#   'text': 'But no.',
#   'start': 246.0,
#   'end': 249.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=249.0s',
#   'text': 'I think for a lot of fans, and you can speak to this,',
#   'start': 249.0,
#   'end': 251.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=251.0s',
#   'text': 'is that a lot of people are coming in as the investment people come in.',
#   'start': 251.0,
#   'end': 255.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=255.0s',
#   'text': 'And it sort of makes it more unaffordable for people who really like cars',
#   'start': 255.0,
#   'end': 258.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=258.0s',
#   'text': 'to get into that market.',
#   'start': 258.0,
#   'end': 260.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=260.0s',
#   'text': "Is that sort of the thing that you're seeing?",
#   'start': 260.0,
#   'end': 261.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=261.0s',
#   'text': "Well, there's an upside and a downsides of both of those.",
#   'start': 261.0,
#   'end': 265.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=265.0s',
#   'text': 'The upside is, as cars become more valuable,',
#   'start': 265.0,
#   'end': 269.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=269.0s',
#   'text': 'people who make parts to fix that vehicle,',
#   'start': 269.0,
#   'end': 272.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=272.0s',
#   'text': 'say, hey, this could be a worthwhile endeavor.',
#   'start': 272.0,
#   'end': 275.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=275.0s',
#   'text': 'Mechanics who repair those vehicles can make a living.',
#   'start': 275.0,
#   'end': 279.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=279.0s',
#   'text': "I mean, there's a college,",
#   'start': 279.0,
#   'end': 281.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=281.0s',
#   'text': 'called McPherson College in Kansas,',
#   'start': 281.0,
#   'end': 284.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=284.0s',
#   'text': 'and they give a four-year degree in automobile restoration.',
#   'start': 284.0,
#   'end': 287.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=287.0s',
#   'text': 'This is the only country in the world where it would be mechanic',
#   'start': 287.0,
#   'end': 289.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=289.0s',
#   'text': "to say, I'm a mechanic.",
#   'start': 289.0,
#   'end': 291.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=291.0s',
#   'text': "There's a garage in Burbank has my favorite sign.",
#   'start': 291.0,
#   'end': 294.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=294.0s',
#   'text': 'It says, we specialize in all makes of cars.',
#   'start': 294.0,
#   'end': 298.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=298.0s',
#   'text': 'Well, how can you specialize in everything?',
#   'start': 298.0,
#   'end': 300.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=300.0s',
#   'text': 'It just sort of makes...',
#   'start': 300.0,
#   'end': 302.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=302.0s',
#   'text': "You've got a Germany, and you have to have a degree.",
#   'start': 302.0,
#   'end': 304.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=304.0s',
#   'text': 'You have a paper that certifies that you are trained mechanic.',
#   'start': 304.0,
#   'end': 307.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=307.0s',
#   'text': 'You work on the car.',
#   'start': 307.0,
#   'end': 308.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=308.0s',
#   'text': "Well, here you just go, I'm a mechanic.",
#   'start': 308.0,
#   'end': 310.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=310.0s',
#   'text': 'Oh, you said he was a mechanic.',
#   'start': 310.0,
#   'end': 312.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=312.0s',
#   'text': "And you're a mechanic.",
#   'start': 312.0,
#   'end': 313.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=313.0s',
#   'text': 'So there are kids that come out of McPherson College.',
#   'start': 313.0,
#   'end': 317.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=317.0s',
#   'text': 'And they started, you know, a hundred bucks an hour.',
#   'start': 317.0,
#   'end': 319.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=319.0s',
#   'text': 'You go to the classic center in Germany,',
#   'start': 319.0,
#   'end': 322.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=322.0s',
#   'text': 'or a lot of the heritage automakers now have classic centers,',
#   'start': 322.0,
#   'end': 326.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=326.0s',
#   'text': 'where they make parts available for their older cars.',
#   'start': 326.0,
#   'end': 329.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=329.0s',
#   'text': 'And people make...',
#   'start': 329.0,
#   'end': 330.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=330.0s',
#   'text': "It's like restoring the old masters' paintings",
#   'start': 330.0,
#   'end': 333.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=333.0s',
#   'text': 'and things of that nature.',
#   'start': 333.0,
#   'end': 334.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=334.0s',
#   'text': "So that's the upside to it.",
#   'start': 334.0,
#   'end': 337.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=337.0s',
#   'text': "You know, I can remember you could buy D.D. 5-Aston Martin's",
#   'start': 337.0,
#   'end': 340.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=340.0s',
#   'text': 'for $2,500.',
#   'start': 340.0,
#   'end': 342.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=342.0s',
#   'text': 'I mean, they were just another old car.',
#   'start': 342.0,
#   'end': 345.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=345.0s',
#   'text': 'And then the James Bond phenomenon and all of that.',
#   'start': 345.0,
#   'end': 348.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=348.0s',
#   'text': 'And then it just hit the roof.',
#   'start': 348.0,
#   'end': 350.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=350.0s',
#   'text': "And now they're a million three, a million five.",
#   'start': 350.0,
#   'end': 353.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=353.0s',
#   'text': 'But more being safe.',
#   'start': 353.0,
#   'end': 355.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=355.0s',
#   'text': 'Cars that would have been thrown away as parts cars,',
#   'start': 355.0,
#   'end': 357.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=357.0s',
#   'text': 'and how being taken back and restored.',
#   'start': 357.0,
#   'end': 359.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=359.0s',
#   'text': 'So there is a flip side to that, enthusiasm?',
#   'start': 359.0,
#   'end': 361.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=361.0s',
#   'text': "Yeah, I think that's okay.",
#   'start': 361.0,
#   'end': 363.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=363.0s',
#   'text': 'I mean, the idea is to get it on the market before everybody else says,',
#   'start': 363.0,
#   'end': 367.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=367.0s',
#   'text': 'trying to figure out what a modern collectible will be.',
#   'start': 367.0,
#   'end': 370.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=370.0s',
#   'text': 'For example, to me, a modern collectible would be a first generation Miata.',
#   'start': 370.0,
#   'end': 375.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=375.0s',
#   'text': 'Easy to work on, no airbag, no crazy electronics,',
#   'start': 375.0,
#   'end': 380.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=380.0s',
#   'text': 'and a little bit of electronics, not much.',
#   'start': 380.0,
#   'end': 382.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=382.0s',
#   'text': 'But just simple, fun to drive, nice to look at, clean design.',
#   'start': 382.0,
#   'end': 388.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=388.0s',
#   'text': 'That would be an example.',
#   'start': 388.0,
#   'end': 390.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=390.0s',
#   'text': 'The Taurus show from the late 80s, that front wheel drive,',
#   'start': 390.0,
#   'end': 394.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=394.0s',
#   'text': 'that Yamaha V6 engine, very powerful, very fast.',
#   'start': 394.0,
#   'end': 398.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=398.0s',
#   'text': "The idea is to try and, if you're knowledgeable about automobiles,",
#   'start': 398.0,
#   'end': 402.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=402.0s',
#   'text': 'and you like cars, whatever you like,',
#   'start': 402.0,
#   'end': 404.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=404.0s',
#   'text': "we'll probably go up in value, because other people will like it too.",
#   'start': 404.0,
#   'end': 408.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=408.0s',
#   'text': 'So you try to keep ahead of the market.',
#   'start': 408.0,
#   'end': 410.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=410.0s',
#   'text': "I know you're a big EV evangelist.",
#   'start': 410.0,
#   'end': 412.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=412.0s',
#   'text': 'You own a Tesla for many years, and you have even the plan now for a while.',
#   'start': 412.0,
#   'end': 416.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=416.0s',
#   'text': 'Elon Musk just said that they sold their 3 millionth car about a month ago.',
#   'start': 416.0,
#   'end': 421.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=421.0s',
#   'text': 'Do you think anyone can catch up with Tesla and Musk right now,',
#   'start': 421.0,
#   'end': 423.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=423.0s',
#   'text': "or are they sort of in the driver's seat when it comes to you?",
#   'start': 423.0,
#   'end': 425.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=425.0s',
#   'text': 'Well, the thing you have to realize about Elon, which is very clever,',
#   'start': 425.0,
#   'end': 429.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=429.0s',
#   'text': 'he came to this garage in 2007 with his prototype, the roadster.',
#   'start': 429.0,
#   'end': 434.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=434.0s',
#   'text': 'And that early when I had a two-speed transmission and a couple other things.',
#   'start': 434.0,
#   'end': 438.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=438.0s',
#   'text': 'Right.',
#   'start': 438.0,
#   'end': 439.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=439.0s',
#   'text': 'And I remember sitting and he was telling me about,',
#   'start': 439.0,
#   'end': 442.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=442.0s',
#   'text': 'he said, well, what I want to do is build charging stations all up and down the coast,',
#   'start': 442.0,
#   'end': 445.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=445.0s',
#   'text': "and I'm going, okay, that'll happen.",
#   'start': 445.0,
#   'end': 447.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=447.0s',
#   'text': 'That sounds good.',
#   'start': 447.0,
#   'end': 449.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=449.0s',
#   'text': 'But you know, he started building the infrastructure,',
#   'start': 449.0,
#   'end': 452.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=452.0s',
#   'text': "almost at the exact time, it's time you started building the car.",
#   'start': 452.0,
#   'end': 456.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=456.0s',
#   'text': 'So when the car debuted, you could drive L.A. to San Francisco,',
#   'start': 456.0,
#   'end': 460.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=460.0s',
#   'text': 'and now you can go anywhere in the country.',
#   'start': 460.0,
#   'end': 463.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=463.0s',
#   'text': 'I mean, you see a lot of other automakers get in the EV market.',
#   'start': 463.0,
#   'end': 467.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=467.0s',
#   'text': 'Oh, you can charge it anywhere.',
#   'start': 467.0,
#   'end': 469.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=469.0s',
#   'text': "No, you can't really.",
#   'start': 469.0,
#   'end': 470.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=470.0s',
#   'text': "You might, but it's 110.",
#   'start': 470.0,
#   'end': 471.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=471.0s',
#   'text': "You're going to be here 18 hours.",
#   'start': 471.0,
#   'end': 473.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=473.0s',
#   'text': 'And you know, so I think he should get a certain amount of credit for leading the charge.',
#   'start': 473.0,
#   'end': 479.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=479.0s',
#   'text': "Because before Elon, oh, it's a golf cart.",
#   'start': 479.0,
#   'end': 483.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=483.0s',
#   'text': 'People would joke about electric.',
#   'start': 483.0,
#   'end': 485.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=485.0s',
#   'text': "Oh, they're slow, whatever it might be.",
#   'start': 485.0,
#   'end': 487.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=487.0s',
#   'text': 'So I give him a lot of credit for it.',
#   'start': 487.0,
#   'end': 490.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=490.0s',
#   'text': 'I mean, I think the EV will be the savior of the classic car industry.',
#   'start': 490.0,
#   'end': 494.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=494.0s',
#   'text': 'Really?',
#   'start': 494.0,
#   'end': 495.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=495.0s',
#   'text': 'Yeah, because much like the automobile was the savior of the American horse.',
#   'start': 495.0,
#   'end': 501.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=501.0s',
#   'text': 'You know, in 1900 in New York City, 60 tons of manure were dropped on the street every day.',
#   'start': 501.0,
#   'end': 508.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=508.0s',
#   'text': 'I mean, people got dysentery and hot weather horses.',
#   'start': 508.0,
#   'end': 511.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=511.0s',
#   'text': "Like a junk man's horse would drop dead in the street that cut the rings and lead the carcass.",
#   'start': 511.0,
#   'end': 515.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=515.0s',
#   'text': 'And the thing would rot and people would get.',
#   'start': 515.0,
#   'end': 517.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=517.0s',
#   'text': 'And all of a sudden, Henry Ford comes along with a Model T and blows a little puff of blue smoke in your face.',
#   'start': 517.0,
#   'end': 522.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=522.0s',
#   'text': "Oh, I'll take blue smoke over manure, I need it.",
#   'start': 522.0,
#   'end': 525.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=525.0s',
#   'text': 'You know, I said, so that was, oh, okay.',
#   'start': 525.0,
#   'end': 527.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=527.0s',
#   'text': 'So now horses are primarily for recreation.',
#   'start': 527.0,
#   'end': 530.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=530.0s',
#   'text': 'And there are more horses now than they were in the mid-1800s.',
#   'start': 530.0,
#   'end': 533.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=533.0s',
#   'text': 'Because people use them for enjoyment and beauty and they take care of them.',
#   'start': 533.0,
#   'end': 539.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=539.0s',
#   'text': "And that's the same thing with cars.",
#   'start': 539.0,
#   'end': 540.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=540.0s',
#   'text': "You'll be using your EV to set on the 4 or 5.",
#   'start': 540.0,
#   'end': 543.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=543.0s',
#   'text': 'I mean, sitting on the 4 or 5 freeway in a 4 or 26,',
#   'start': 543.0,
#   'end': 546.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=546.0s',
#   'text': 'Henry getting 8 miles to gallon makes no sense at all.',
#   'start': 546.0,
#   'end': 549.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=549.0s',
#   'text': 'So you drive your EV, then on the weekends, okay, you take your Henry,',
#   'start': 549.0,
#   'end': 552.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=552.0s',
#   'text': 'you go to the car show, you go to Bob the big boy, whatever it might be.',
#   'start': 552.0,
#   'end': 556.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=556.0s',
#   'text': 'Yeah, you know, because you have a steam car, car in the 4 or 5.',
#   'start': 556.0,
#   'end': 559.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=559.0s',
#   'text': 'Not the best option.',
#   'start': 559.0,
#   'end': 560.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=560.0s',
#   'text': 'Right, right.',
#   'start': 560.0,
#   'end': 561.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=561.0s',
#   'text': 'So you mentioned Ford, I wanted to talk to you about that.',
#   'start': 561.0,
#   'end': 564.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=564.0s',
#   'text': "Jim Farley, I spoke to him about Monterey and he's a big car guy.",
#   'start': 564.0,
#   'end': 567.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=567.0s',
#   'text': "He's racing cars that we're going to say.",
#   'start': 567.0,
#   'end': 569.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=569.0s',
#   'text': 'He also split the business into two units to sort of capitalize on.',
#   'start': 569.0,
#   'end': 573.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=573.0s',
#   'text': 'Well, fast.',
#   'start': 573.0,
#   'end': 574.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=574.0s',
#   'text': "That's why I'm very proud of American manufacturing.",
#   'start': 574.0,
#   'end': 577.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=577.0s',
#   'text': "Everybody in Ford, GM Dodge, they're all engineers now.",
#   'start': 577.0,
#   'end': 582.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=582.0s',
#   'text': 'In the old age of this, this was Bob from Admiral Washington,',
#   'start': 582.0,
#   'end': 586.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=586.0s',
#   'text': "he's going to help us with the marketing of this.",
#   'start': 586.0,
#   'end': 589.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=589.0s',
#   'text': "He's a Maytag.",
#   'start': 589.0,
#   'end': 590.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=590.0s',
#   'text': 'Yeah, Maytag.',
#   'start': 590.0,
#   'end': 591.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=591.0s',
#   'text': "I mean, that's what they did.",
#   'start': 591.0,
#   'end': 592.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=592.0s',
#   'text': 'They brought marketing people in and they put go fast stripes on it',
#   'start': 592.0,
#   'end': 596.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=596.0s',
#   'text': 'like a Ferrari.',
#   'start': 596.0,
#   'end': 597.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=597.0s',
#   'text': "It's got a stripe on the hood, just like a Ferrari.",
#   'start': 597.0,
#   'end': 599.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=599.0s',
#   'text': 'But now, you got, he got Royce, president of GM.',
#   'start': 599.0,
#   'end': 604.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=604.0s',
#   'text': "He's at Nürburgring, set records with Cadillac.",
#   'start': 604.0,
#   'end': 607.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=607.0s',
#   'text': "I mean, it's very funny.",
#   'start': 607.0,
#   'end': 608.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=608.0s',
#   'text': 'But you have real engineers.',
#   'start': 608.0,
#   'end': 610.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=610.0s',
#   'text': 'The businesses are lean.',
#   'start': 610.0,
#   'end': 611.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=611.0s',
#   'text': 'How they build a Corvette for $65,000.',
#   'start': 611.0,
#   'end': 614.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=614.0s',
#   'text': 'I have no idea.',
#   'start': 614.0,
#   'end': 616.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=616.0s',
#   'text': 'I could barely paint one and restore one for that.',
#   'start': 616.0,
#   'end': 619.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=619.0s',
#   'text': "So the fact that it's done in a union shop",
#   'start': 619.0,
#   'end': 622.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=622.0s',
#   'text': "and it's using high grade and a lot of magnesium,",
#   'start': 622.0,
#   'end': 625.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=625.0s',
#   'text': 'a lot of aluminum.',
#   'start': 625.0,
#   'end': 626.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=626.0s',
#   'text': "It's not steel and torque and rotor transmissions.",
#   'start': 626.0,
#   'end': 630.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=630.0s',
#   'text': "It's dual clutches.",
#   'start': 630.0,
#   'end': 631.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=631.0s',
#   'text': "I mean, I'm really quite proud of American manufacturing.",
#   'start': 631.0,
#   'end': 634.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=634.0s',
#   'text': "It's done an amazing job.",
#   'start': 634.0,
#   'end': 635.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=635.0s',
#   'text': 'You know that Corvette kind of, my first son drove in it.',
#   'start': 635.0,
#   'end': 638.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=638.0s',
#   'text': 'Or mine, it might be the McLaren.',
#   'start': 638.0,
#   'end': 639.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=639.0s',
#   'text': 'And for like you said, the third of the price.',
#   'start': 639.0,
#   'end': 641.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=641.0s',
#   'text': 'For the third of the price.',
#   'start': 641.0,
#   'end': 642.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=642.0s',
#   'text': 'And it kind of brings you back to, you know, you got Mary Barrett, GM.',
#   'start': 642.0,
#   'end': 644.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=644.0s',
#   'text': 'You know, Jim Farley at Ford.',
#   'start': 644.0,
#   'end': 646.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=646.0s',
#   'text': 'Do you think either one of those is sort of the next level of,',
#   'start': 646.0,
#   'end': 649.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=649.0s',
#   'text': 'from the EV kind of like, you know, high arc here,',
#   'start': 649.0,
#   'end': 652.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=652.0s',
#   'text': "like Tesla, do you think it's Ford or GM?",
#   'start': 652.0,
#   'end': 654.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=654.0s',
#   'text': "That'll be kind of the next level in terms of that kind of competition.",
#   'start': 654.0,
#   'end': 657.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=657.0s',
#   'text': "Well, I think America's self has always been about egalitarianism",
#   'start': 657.0,
#   'end': 662.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=662.0s',
#   'text': 'making it available to everybody.',
#   'start': 662.0,
#   'end': 664.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=664.0s',
#   'text': 'You know, the smart thing about America was',
#   'start': 664.0,
#   'end': 668.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=668.0s',
#   'text': 'anybody could buy a Model T.',
#   'start': 668.0,
#   'end': 670.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=670.0s',
#   'text': 'The idea in Germany or France of the average person only going on an automobile.',
#   'start': 670.0,
#   'end': 675.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=675.0s',
#   'text': 'I mean, it just seemed ridiculous.',
#   'start': 675.0,
#   'end': 678.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=678.0s',
#   'text': 'But to make something affordable, you know, like to me,',
#   'start': 678.0,
#   'end': 682.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=682.0s',
#   'text': "the greatest book ever written is still Jell's Dickens or Christmas Carol.",
#   'start': 682.0,
#   'end': 686.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=686.0s',
#   'text': 'Because it was popular, it was accessible,',
#   'start': 686.0,
#   'end': 689.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=689.0s',
#   'text': 'it was the first time you could improve your life without having to die first,',
#   'start': 689.0,
#   'end': 693.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=693.0s',
#   'text': 'go to heaven and come back.',
#   'start': 693.0,
#   'end': 695.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=695.0s',
#   'text': 'You could just change your life just by being a nice person.',
#   'start': 695.0,
#   'end': 698.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=698.0s',
#   'text': 'And this was a concept that people just thought was unbelievable when I came out.',
#   'start': 698.0,
#   'end': 702.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=702.0s',
#   'text': 'Oh, this rich man helps this poor man.',
#   'start': 702.0,
#   'end': 705.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=705.0s',
#   'text': 'And both their lives are improved.',
#   'start': 705.0,
#   'end': 708.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=708.0s',
#   'text': 'How simple could it be, you know?',
#   'start': 708.0,
#   'end': 710.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=710.0s',
#   'text': "And that's what it is.",
#   'start': 710.0,
#   'end': 711.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=711.0s',
#   'text': 'America was never about building premium automobile.',
#   'start': 711.0,
#   'end': 714.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=714.0s',
#   'text': "It's about building working classes.",
#   'start': 714.0,
#   'end': 717.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=717.0s',
#   'text': 'I used to call it, or I mean, of course you build premium automobiles now.',
#   'start': 717.0,
#   'end': 720.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=720.0s',
#   'text': "But I mean, I think that's the key.",
#   'start': 720.0,
#   'end': 721.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=721.0s',
#   'text': "It's volume really is what it does.",
#   'start': 721.0,
#   'end': 723.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=723.0s',
#   'text': 'Yeah, it seems like, you know, these days with such skyrocketing new car prices,',
#   'start': 723.0,
#   'end': 726.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=726.0s',
#   'text': 'the blue collar, your mainstream kind of guy is buying used cars to survive.',
#   'start': 726.0,
#   'end': 731.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=731.0s',
#   'text': 'Right.',
#   'start': 731.0,
#   'end': 732.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=732.0s',
#   'text': 'But I wanted to talk to you about that about affordability.',
#   'start': 732.0,
#   'end': 734.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=734.0s',
#   'text': 'And again, the Ford will quick about that.',
#   'start': 734.0,
#   'end': 736.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=736.0s',
#   'text': 'The new F-150 Lightning, an electric truck that, you know,',
#   'start': 736.0,
#   'end': 739.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=739.0s',
#   'text': 'is promising to come in at a competitive price point.',
#   'start': 739.0,
#   'end': 742.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=742.0s',
#   'text': 'I drove it.',
#   'start': 742.0,
#   'end': 743.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=743.0s',
#   'text': "I think it's a great truck.",
#   'start': 743.0,
#   'end': 744.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=744.0s',
#   'text': "You know, it's amazing.",
#   'start': 744.0,
#   'end': 745.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=745.0s',
#   'text': 'You can weld in that truck.',
#   'start': 745.0,
#   'end': 746.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=746.0s',
#   'text': "It's got 240 in the back.",
#   'start': 746.0,
#   'end': 747.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=747.0s',
#   'text': 'Yeah.',
#   'start': 747.0,
#   'end': 748.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=748.0s',
#   'text': 'So do you think that, you know, your guy works at a work site, construction worker,',
#   'start': 748.0,
#   'end': 752.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=752.0s',
#   'text': 'really a professional kind of tradesman?',
#   'start': 752.0,
#   'end': 755.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=755.0s',
#   'text': 'Are they going to go hop on board the F-150 Lightning?',
#   'start': 755.0,
#   'end': 757.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=757.0s',
#   'text': 'Yes.',
#   'start': 757.0,
#   'end': 758.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=758.0s',
#   'text': 'You know what?',
#   'start': 758.0,
#   'end': 759.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=759.0s',
#   'text': 'This is what I want.',
#   'start': 759.0,
#   'end': 760.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=760.0s',
#   'text': 'Yes.',
#   'start': 760.0,
#   'end': 761.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=761.0s',
#   'text': 'You know why I know that?',
#   'start': 761.0,
#   'end': 762.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=762.0s',
#   'text': 'Because in the 50s, trucks had a bench seat, three speed on the column,',
#   'start': 762.0,
#   'end': 766.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=766.0s',
#   'text': 'and a six-cylinder engine.',
#   'start': 766.0,
#   'end': 768.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=768.0s',
#   'text': 'You know, air conditioning and a truck.',
#   'start': 768.0,
#   'end': 770.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=770.0s',
#   'text': 'What do you miss to the, what do you own of the final?',
#   'start': 770.0,
#   'end': 772.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=772.0s',
#   'text': 'This guy.',
#   'start': 772.0,
#   'end': 773.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=773.0s',
#   'text': 'I mean, you were in a man, you know, trucks were manly things that come up of a, you know,',
#   'start': 773.0,
#   'end': 777.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=777.0s',
#   'text': 'and then all of a sudden, all of a sudden, oh, you have air.',
#   'start': 777.0,
#   'end': 780.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=780.0s',
#   'text': 'I mean, an F-150 is basically a Lincoln.',
#   'start': 780.0,
#   'end': 784.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=784.0s',
#   'text': "It's comfortable.",
#   'start': 784.0,
#   'end': 786.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=786.0s',
#   'text': 'You can do everything with it.',
#   'start': 786.0,
#   'end': 788.0},
# ...
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1007.0s',
#   'text': 'In addition to the rocket science, right?',
#   'start': 1007.0,
#   'end': 1009.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1009.0s',
#   'text': 'Yeah, I mean, he understands.',
#   'start': 1009.0,
#   'end': 1011.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1011.0s',
#   'text': "It's like Elon says right now, of course, over a billion dollars,",
#   'start': 1011.0,
#   'end': 1014.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1014.0s',
#   'text': 'put one gallon of water on Mars.',
#   'start': 1014.0,
#   'end': 1018.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1018.0s',
#   'text': 'He wants to get that down to a hundred thousand dollars a gallon,',
#   'start': 1018.0,
#   'end': 1021.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1021.0s',
#   'text': "which is still crazy, but it's not a billion, you know.",
#   'start': 1021.0,
#   'end': 1025.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1025.0s',
#   'text': 'And so just that thinking outside the box thing, which I find uniquely American, you know.',
#   'start': 1025.0,
#   'end': 1031.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1031.0s',
#   'text': "That's why I never got this, I always felt bad with this banning of immigrants thing that they had a few years ago, you know.",
#   'start': 1031.0,
#   'end': 1041.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1041.0s',
#   'text': 'With shutting the, you know, Steve Jobs was Syrian.',
#   'start': 1041.0,
#   'end': 1044.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1044.0s',
#   'text': 'I mean, all the doctors, all the people who come from India, you know,',
#   'start': 1044.0,
#   'end': 1049.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1049.0s',
#   'text': 'America will seduce you with hamburgers and autos and music.',
#   'start': 1049.0,
#   'end': 1053.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1053.0s',
#   'text': 'My favorite example is, we used to do this J-walking thing,',
#   'start': 1053.0,
#   'end': 1056.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1056.0s',
#   'text': "we would knock on doors, that's a few questions.",
#   'start': 1056.0,
#   'end': 1058.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1058.0s',
#   'text': 'I remember going to one else, knock on door.',
#   'start': 1058.0,
#   'end': 1060.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1060.0s',
#   'text': "And the grandfather answered the door and he's got a vest and a tie and he speaks Spanish.",
#   'start': 1060.0,
#   'end': 1065.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1065.0s',
#   'text': "He goes, no, he's not, oh, okay, his son comes over,",
#   'start': 1065.0,
#   'end': 1069.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1069.0s',
#   'text': 'a little fatter than his dad, a little heavier, kind of sloppy.',
#   'start': 1069.0,
#   'end': 1074.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1074.0s',
#   'text': 'He speaks English, talks to me, so and so.',
#   'start': 1074.0,
#   'end': 1077.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1077.0s',
#   'text': "Then I meet his son, he's got a t-shirt with some obscenity on it.",
#   'start': 1077.0,
#   'end': 1081.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1081.0s',
#   'text': 'You know, just a deterioration.',
#   'start': 1081.0,
#   'end': 1083.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1083.0s',
#   'text': 'For Greshan, no.',
#   'start': 1083.0,
#   'end': 1084.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1084.0s',
#   'text': 'The progression of downhill.',
#   'start': 1084.0,
#   'end': 1085.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1085.0s',
#   'text': "You can see the grandfather is the fittest one in the family because he's the immigrant.",
#   'start': 1085.0,
#   'end': 1089.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1089.0s',
#   'text': 'He came, he worked hard and everybody else is property.',
#   'start': 1089.0,
#   'end': 1092.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1092.0s',
#   'text': "And that's what America's about.",
#   'start': 1092.0,
#   'end': 1093.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1093.0s',
#   'text': 'You bring these immigrants in and they invent stuff and they become citizens.',
#   'start': 1093.0,
#   'end': 1097.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1097.0s',
#   'text': "It's a great place to live.",
#   'start': 1097.0,
#   'end': 1099.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1099.0s',
#   'text': 'The pizza is great, the music is fun, the girls are beautiful.',
#   'start': 1099.0,
#   'end': 1103.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1103.0s',
#   'text': "That's what happens.",
#   'start': 1103.0,
#   'end': 1104.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1104.0s',
#   'text': 'You meet new immigrants all the time.',
#   'start': 1104.0,
#   'end': 1106.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1106.0s',
#   'text': 'You know, I visited with the Zinger guys the other day.',
#   'start': 1106.0,
#   'end': 1109.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1109.0s',
#   'text': "I know they're coming up on your show today.",
#   'start': 1109.0,
#   'end': 1111.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1111.0s',
#   'text': 'Yeah, right, right.',
#   'start': 1111.0,
#   'end': 1112.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1112.0s',
#   'text': 'Father and son team.',
#   'start': 1112.0,
#   'end': 1113.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1113.0s',
#   'text': 'Great story there.',
#   'start': 1113.0,
#   'end': 1115.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1115.0s',
#   'text': 'American manufacturing again.',
#   'start': 1115.0,
#   'end': 1116.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1116.0s',
#   'text': 'Right.',
#   'start': 1116.0,
#   'end': 1117.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1117.0s',
#   'text': 'And so I guess this season you mean highlighting a lot of these kinds of things.',
#   'start': 1117.0,
#   'end': 1119.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1119.0s',
#   'text': 'We highlight them.',
#   'start': 1119.0,
#   'end': 1120.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1120.0s',
#   'text': 'We have them on the show.',
#   'start': 1120.0,
#   'end': 1121.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1121.0s',
#   'text': 'We have Elon.',
#   'start': 1121.0,
#   'end': 1122.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1122.0s',
#   'text': "I'm shooting this week with President Biden.",
#   'start': 1122.0,
#   'end': 1126.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1126.0s',
#   'text': "We're doing, oh wow.",
#   'start': 1126.0,
#   'end': 1127.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1127.0s',
#   'text': "Yeah, he's a car guy.",
#   'start': 1127.0,
#   'end': 1128.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1128.0s',
#   'text': "You know, he's still got his six-compete.",
#   'start': 1128.0,
#   'end': 1130.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1130.0s',
#   'text': "That's a corporate guy.",
#   'start': 1130.0,
#   'end': 1131.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1131.0s',
#   'text': 'Yeah, yeah, yeah.',
#   'start': 1131.0,
#   'end': 1132.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1132.0s',
#   'text': "So we're going to have some fun and take some EVs out and talk about that.",
#   'start': 1132.0,
#   'end': 1136.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1136.0s',
#   'text': "Yeah, it's a great show to do.",
#   'start': 1136.0,
#   'end': 1140.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1140.0s',
#   'text': 'The idea is everybody has some connection with the car.',
#   'start': 1140.0,
#   'end': 1143.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1143.0s',
#   'text': 'You know, it talks to celebrities all the time and they go,',
#   'start': 1143.0,
#   'end': 1145.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1145.0s',
#   'text': "I don't know nothing about cars.",
#   'start': 1145.0,
#   'end': 1147.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1147.0s',
#   'text': 'I said, well, did you ever do anything with the car with your dad?',
#   'start': 1147.0,
#   'end': 1150.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1150.0s',
#   'text': 'Oh, when I was a kid, my dad had a Cadillac.',
#   'start': 1150.0,
#   'end': 1152.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1152.0s',
#   'text': 'And we go for ice cream every Sunday.',
#   'start': 1152.0,
#   'end': 1154.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1154.0s',
#   'text': 'Cadillac gets a celebrity.',
#   'start': 1154.0,
#   'end': 1156.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1156.0s',
#   'text': 'Go for ice cream on a Sunday.',
#   'start': 1156.0,
#   'end': 1158.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1158.0s',
#   'text': 'And talk about it.',
#   'start': 1158.0,
#   'end': 1159.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1159.0s',
#   'text': "You know, and that's pretty much it.",
#   'start': 1159.0,
#   'end': 1161.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1161.0s',
#   'text': 'I mean, the car is a huge part of, I think, of American culture.',
#   'start': 1161.0,
#   'end': 1164.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1164.0s',
#   'text': 'Right?',
#   'start': 1164.0,
#   'end': 1165.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1165.0s',
#   'text': 'You know, lastly, Jay, I know that you also have various other business interests.',
#   'start': 1165.0,
#   'end': 1168.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1168.0s',
#   'text': 'And one thing I discovered was you have a business where you,',
#   'start': 1168.0,
#   'end': 1171.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1171.0s',
#   'text': 'all these cars are detailed and cleaned with a specific product.',
#   'start': 1171.0,
#   'end': 1176.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1176.0s',
#   'text': 'Well, you know, we developed our own product.',
#   'start': 1176.0,
#   'end': 1178.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1178.0s',
#   'text': 'Yeah, I mean, the smart way to do it is a big company comes along like 3M or something.',
#   'start': 1178.0,
#   'end': 1183.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1183.0s',
#   'text': 'It gives you a huge check and you hold up.',
#   'start': 1183.0,
#   'end': 1185.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1185.0s',
#   'text': 'Well, this is the, you know, we developed our own stuff here.',
#   'start': 1185.0,
#   'end': 1190.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1190.0s',
#   'text': 'We quietly put it out just to see how people react to it.',
#   'start': 1190.0,
#   'end': 1193.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1193.0s',
#   'text': 'We got great reaction.',
#   'start': 1193.0,
#   'end': 1194.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1194.0s',
#   'text': 'People liked it.',
#   'start': 1194.0,
#   'end': 1195.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1195.0s',
#   'text': 'People ordered and then re-ordered.',
#   'start': 1195.0,
#   'end': 1197.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1197.0s',
#   'text': "And now we're national, we're in Walmart and a bunch of these big stores.",
#   'start': 1197.0,
#   'end': 1201.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1201.0s',
#   'text': 'I expect the usual snarkiness.',
#   'start': 1201.0,
#   'end': 1203.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1203.0s',
#   'text': "No, Jay Zanold, you're trying to cash in.",
#   'start': 1203.0,
#   'end': 1206.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1206.0s',
#   'text': 'Okay, maybe.',
#   'start': 1206.0,
#   'end': 1208.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1208.0s',
#   'text': "But it's a good product.",
#   'start': 1208.0,
#   'end': 1210.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1210.0s',
#   'text': "People seem to like it and it's doing well.",
#   'start': 1210.0,
#   'end': 1212.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1212.0s',
#   'text': 'So keep up with your fingers crossed.',
#   'start': 1212.0,
#   'end': 1213.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1213.0s',
#   'text': 'Yeah, I mean, I heard you have your own chemistry.',
#   'start': 1213.0,
#   'end': 1215.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1215.0s',
#   'text': "It's not just something you just, you're laboring.",
#   'start': 1215.0,
#   'end': 1216.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1216.0s',
#   'text': 'No, no, we developed everything here at the shop.',
#   'start': 1216.0,
#   'end': 1218.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1218.0s',
#   'text': 'We tried out on all of my stuff and it seems pretty good.',
#   'start': 1218.0,
#   'end': 1221.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1221.0s',
#   'text': "I mean, the one that got us started was cars don't have chrome.",
#   'start': 1221.0,
#   'end': 1226.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1226.0s',
#   'text': "Cars don't have chrome anymore.",
#   'start': 1226.0,
#   'end': 1228.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1228.0s',
#   'text': 'Yeah, not to speak of.',
#   'start': 1228.0,
#   'end': 1230.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1230.0s',
#   'text': 'And polishes.',
#   'start': 1230.0,
#   'end': 1232.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1232.0s',
#   'text': 'And I would use other polishes.',
#   'start': 1232.0,
#   'end': 1234.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1234.0s',
#   'text': "I noticed on the rag, I'd see, you know, metallic specs.",
#   'start': 1234.0,
#   'end': 1238.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1238.0s',
#   'text': "You know, like, oh, it's actually peeling off a layer of the chrome.",
#   'start': 1238.0,
#   'end': 1241.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1241.0s',
#   'text': "So I said, let's find a company and develop a chemical that cleans",
#   'start': 1241.0,
#   'end': 1245.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1245.0s',
#   'text': 'without having an abrasive, you know.',
#   'start': 1245.0,
#   'end': 1248.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1248.0s',
#   'text': "And that's what we did.",
#   'start': 1248.0,
#   'end': 1249.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1249.0s',
#   'text': "That's one that first took off.",
#   'start': 1249.0,
#   'end': 1251.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1251.0s',
#   'text': 'And then we built the whole company around that.',
#   'start': 1251.0,
#   'end': 1253.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1253.0s',
#   'text': "So we'll see these products in Walmart and now Big Deal coming up.",
#   'start': 1253.0,
#   'end': 1255.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1255.0s',
#   'text': 'And seven season of the show coming up later this month.',
#   'start': 1255.0,
#   'end': 1258.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1258.0s',
#   'text': 'So Jay, thanks again for joining us.',
#   'start': 1258.0,
#   'end': 1260.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1260.0s',
#   'text': 'Thanks.',
#   'start': 1260.0,
#   'end': 1261.0},
#  {'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=1261.0s',
#   'text': 'Appreciate it.',
#   'start': 1261.0,
#   'end': 1262.0}]

# %%
len(transcript_data)

# %%
transcript_data[0:5]

# %%
# combining each 6 (window) transcript segments into one, with overlabbing of 3 
# segments =(stride), these number might need fine tunnig to obtain the most 
# meaningful semgentation
transcript_new_data = []
window = 6  # number of segments to combine
stride = 3  # number of segments to 'stride' over, used to create overlap
for i in (range(0, len(transcript_data), stride)):
    i_end = min(len(transcript_data)-1, i+window)
    text = ' '.join(_['text'] for _ in transcript_data[i:i_end])
    transcript_new_data.append({
        'start': transcript_data[i]['start'],
        'end': transcript_data[i_end]['end'],
        'text': text,
        'id': transcript_data[i]['id'],
    })

# %%
len(transcript_new_data)
# Out:
# 161

# %%
transcript_new_data[0:5]
# Out:
# [{'start': 0.0,
#   'end': 19.0,
#   'text': "So Catholics have the Vatican. Soccer fans, old Trapperton Manchester. And for car guys like me, Jay Leno's garage. Jay, thanks again for bringing us here. Thank you guys for wondering where they're going. Catholics have the Vatican.",
#   'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=0.0s'},
#  {'start': 13.0,
#   'end': 23.0,
#   'text': "Jay, thanks again for bringing us here. Thank you guys for wondering where they're going. Catholics have the Vatican. I go, oh, what is it? It's totally different. I am in the wrong, oh, I see.",
#   'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=13.0s'},
#  {'start': 18.0,
#   'end': 26.0,
#   'text': "I go, oh, what is it? It's totally different. I am in the wrong, oh, I see. But you guys see, you make you comprise. Yeah, you know. That's why you live in the Vatican.",
#   'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=18.0s'},
#  {'start': 21.0,
#   'end': 29.0,
#   'text': "But you guys see, you make you comprise. Yeah, you know. That's why you live in the Vatican. You know, you're in the Vatican. You know, you're in the Vatican. You know, you're in the Vatican.",
#   'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=21.0s'},
#  {'start': 25.0,
#   'end': 34.0,
#   'text': "You know, you're in the Vatican. You know, you're in the Vatican. You know, you're in the Vatican. You're in the Vatican. You know, that's why you live people finish what they're saying. You know, I try, right?",
#   'id': 'https://www.youtube.com/watch?v=kSu7fNDKqvM&t=25.0s'}]

# %%
# imports
import pandas as pd
import tiktoken
from openai.embeddings_utils import get_embedding, cosine_similarity
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tiktoken
#   Downloading tiktoken-0.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.8/dist-packages (from tiktoken) (2022.6.2)
# Collecting blobfile>=2
#   Downloading blobfile-2.0.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 7.9 MB/s eta 0:00:00
# Collecting requests>=2.26.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: lxml~=4.9 in /usr/local/lib/python3.8/dist-packages (from blobfile>=2->tiktoken) (4.9.2)
# Requirement already satisfied: filelock~=3.0 in /usr/local/lib/python3.8/dist-packages (from blobfile>=2->tiktoken) (3.9.0)
# Requirement already satisfied: urllib3<3,>=1.25.3 in /usr/local/lib/python3.8/dist-packages (from blobfile>=2->tiktoken) (1.26.14)
# Collecting pycryptodomex~=3.8
#   Downloading pycryptodomex-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 56.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->tiktoken) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->tiktoken) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->tiktoken) (2.10)
# Installing collected packages: requests, pycryptodomex, blobfile, tiktoken
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed blobfile-2.0.1 pycryptodomex-3.17 requests-2.28.2 tiktoken-0.3.0

# %%
# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8000  # the maximum for text-embedding-ada-002 is 8191

# %%
encoding = tiktoken.get_encoding("cl100k_base")
# should print [83, 1609, 5963, 374, 2294, 0]
encoding.encode("tiktoken is great!")
# Out:
# [83, 1609, 5963, 374, 2294, 0]

# %%
df = pd.DataFrame(transcript_new_data)
# noteiced a row with empty text, removing that
df=df[df.text.ne('')]
# encode , I might not need this step
df["n_tokens"] = df.text.apply(lambda x: len(encoding.encode(str(x))))
# filter too long text if any
df = df[df.n_tokens <= max_tokens]
df
# Out:
#       start     end                                               text  \
# 0       0.0    19.0  So Catholics have the Vatican. Soccer fans, ol...
# 1      13.0    23.0  Jay, thanks again for bringing us here. Thank ...
# 2      18.0    26.0  I go, oh, what is it? It's totally different. ...
# 3      21.0    29.0  But you guys see, you make you comprise. Yeah,...
# 4      25.0    34.0  You know, you're in the Vatican. You know, you...
# ..      ...     ...                                                ...
# 155  1226.0  1245.0  Cars don't have chrome anymore. Yeah, not to s...
# 156  1232.0  1251.0  And I would use other polishes. I noticed on t...
# 157  1241.0  1258.0  So I said, let's find a company and develop a ...
# 158  1249.0  1262.0  That's one that first took off. And then we bu...
# 159  1255.0  1262.0  And seven season of the show coming up later t...
#
#                                                     id  n_tokens
# 0    https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        52
# 1    https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        49
# 2    https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        49
# 3    https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        51
# 4    https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        56
# ..                                                 ...       ...
# 155  https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        61
# 156  https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        73
# 157  https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        63
# 158  https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        56
# 159  https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...        23
#
# [160 rows x 5 columns]

# %%
# Out:
# 160

# %%
import openai
openai.api_key = 'sk-ADD YOUR OPENAI API KEY'
df["embedding"] = df.text.apply(lambda x: get_embedding(x, engine=embedding_model))
df[0:5]
# Out:
#    start   end                                               text  \
# 0    0.0  19.0  So Catholics have the Vatican. Soccer fans, ol...
# 1   13.0  23.0  Jay, thanks again for bringing us here. Thank ...
# 2   18.0  26.0  I go, oh, what is it? It's totally different. ...
# 3   21.0  29.0  But you guys see, you make you comprise. Yeah,...
# 4   25.0  34.0  You know, you're in the Vatican. You know, you...
#
#                                                   id  n_tokens  \
# 0  https://www.youtube.com/watch?v=kSu7fNDKqvM&t=...
#  0.021742329001426697,
#  -0.005091473460197449,
#  -0.01511405874043703,
#  -0.005629351828247309,
#  -0.0009037030977196991,
#  -0.02091379463672638,
#  0.023666664958000183,
#  0.026887254789471626,
#  0.005375446751713753,
#  0.004299689084291458,
#  0.2242920994758606,
#  -0.014806699007749557,
#  -0.02059307135641575,
#  0.03022811748087406,
#  0.006675041746348143,
#  0.021381516009569168,
#  0.008124975487589836,
#  -0.00835883617401123,
#  0.0012386244488880038,
#  -0.009247505106031895,
#  -0.016477130353450775,
#  0.015755504369735718,
#  -0.03541313484311104,
#  -0.008913419209420681,
#  -0.013022678904235363,
#  -0.0071293991059064865,
#  -0.0349053218960762,
#  0.007784207817167044,
#  -0.006948992609977722,
#  0.03132392093539238,
#  0.0256043653935194,
#  0.0014290536055341363,
#  0.00030443602008745074,
#  -0.012554958462715149,
#  0.005599284078925848,
#  -0.00572623685002327,
#  0.004269621334969997,
#  -0.006721813697367907,
#  0.010062675923109055,
#  0.005509080830961466,
#  -0.02134142443537712,
#  -0.00233192159794271,
#  0.02243722788989544,
#  0.0031521031633019447,
#  -0.005776349920779467,
#  -0.014673064462840557,
#  0.028731411322951317,
#  -0.005195040255784988,
#  0.025417275726795197,
#  0.022009598091244698,
#  0.022998493164777756,
#  0.0018241105135530233,
#  -0.025778088718652725,
#  0.005195040255784988,
#  -0.008472425863146782,
#  0.0038987856823951006,
#  ...]

# %%
# find the most relevant parts of the video transcript to the query
df["similarity"] = df.embedding.apply(lambda x: cosine_similarity(x, query_embedding))
results = (df.sort_values("similarity", ascending=False).head(3))
results = results.set_index(['id'])

# %%
from IPython.display import HTML
HTML(results[['start','similarity', 'text']].to_html(render_links=True, escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>start</th>
#       <th>similarity</th>
#       <th>text</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th><a href="https://www.youtube.com/watch?v=kSu7fNDKqvM&t=897.0s" target="_blank">https://www.youtube.com/watch?v=kSu7fNDKqvM&t=897.0s</a></th>
#       <td>897.0</td>
#       <td>0.835220</td>
#       <td>Is that, like you said, a taxpayer for trucks, spurred that growth. Are we going to see more EV adoption with that? Oh, sure. I mean, it took 75 years for every American home to have a telephone. It took five years for every American home to have a computer. So I think using that same sort of thing, you see how quickly it's moving now.</td>
#     </tr>
#     <tr>
#       <th><a href="https://www.youtube.com/watch?v=kSu7fNDKqvM&t=892.0s" target="_blank">https://www.youtube.com/watch?v=kSu7fNDKqvM&t=892.0s</a></th>
#       <td>892.0</td>
#       <td>0.831535</td>
#       <td>And I think that's the thing of that. But big, another extension of that taxpayer for EV. Right. Is that, like you said, a taxpayer for trucks, spurred that growth. Are we going to see more EV adoption with that? Oh, sure.</td>
#     </tr>
#     <tr>
#       <th><a href="https://www.youtube.com/watch?v=kSu7fNDKqvM&t=483.0s" target="_blank">https://www.youtube.com/watch?v=kSu7fNDKqvM&t=483.0s</a></th>
#       <td>483.0</td>
#       <td>0.825912</td>
#       <td>People would joke about electric. Oh, they're slow, whatever it might be. So I give him a lot of credit for it. I mean, I think the EV will be the savior of the classic car industry. Really? Yeah, because much like the automobile was the savior of the American horse.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# References: https://lablab.ai/t/whisper-transcribe-youtube-video
